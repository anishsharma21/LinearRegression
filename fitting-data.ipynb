# %%
from LinearRegression import LinearRegression
from DataGenerator import DataGenerator
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = pd.Series(range(0, 101))
data_generator = DataGenerator(x)
y = data_generator.generate_y()
plt.scatter(x, y)

# %%
y = pd.Series(y.flatten())

# %%
lr = LinearRegression()
points = lr.x_y_to_points(x, y)
# Out:
# 101
# 101

# %%
lr.crude_fit()
# Out:
# Error increased when adding learning rate
# ErrorDirection.ERROR_DECREASED
# -540.0
# Error increased when adding learning rate
# ErrorDirection.ERROR_DECREASED
# -2.0

# %%
y_predict = np.array([lr.m * x_val + lr.b for x_val in x]).reshape(-1,1)
plt.scatter(x, y)
plt.plot(x, y_predict)

# %%
lr.standard_fit()
print(lr.b)
print(lr.m)
# Out:
# 28.921845860728208
# -10.37831845722283

# %%
y_predict = np.array([lr.m * x_val + lr.b for x_val in x]).reshape(-1,1)
plt.scatter(x, y)
plt.plot(x, y_predict)
